# %%
import numpy as np
import matplotlib as plt
import pandas as pad
import sympy as sp
import matplotlib.pyplot as plt

# %%
print ("Hola Profesor Felipe")
# Out:
# Hola Profesor Felipe

# %% [markdown]
# # Mi primera tarea en Jupyter
# ## Esta tarea es importante para el curso de patrones
# ### El aprendizaje ha sido interesante
#
# La tarea ha sido interesante
# -Aprendizaje 1 *Importante*
# -Aprendizaje 2 **Importante**
#
# [imagen](https://docs.python-guide.org/scenarios/imaging/)

# %%
print ('Definiendo variable X')

X=10
# Out:
# Definiendo variable X

# %%
print ('Desplejando resultado de variable X')

print ("variable:",X)
# Out:
# Desplejando resultado de variable X
# variable: 10

# %%
print ('Definiendo variable Y')

Y=5
# Out:
# Definiendo variable Y

# %%
print ('Resultado')

print ("variable:",Y*X)
# Out:
# Resultado
# variable: 50

# %%
def f(x):
    return np.sin(x)

func = sp.Function ("func")

x = sp.Symbol('x')

func = sp.sin(x)
display (func)

inte = sp.Integral (func,x)
display (inte)
answer = sp.integrate (func,x)
display (answer)
deriv = sp.diff (func,x)
display (deriv)
# Out:
# sin(x)
# Integral(sin(x), x)
# -cos(x)
# cos(x)

# %%
# Data for plotting 
t = np.arange(0.0, 2.0, 0.01) 
s = 1 +np.cos(2 * np.pi * t) 

fig, ax = plt.subplots()
ax.plot(t, s) 

ax.set(xlabel='time (s)', ylabel='voltage (mV)', 
       title='COS Function')
ax.grid() 

fig.savefig("test.png")
plt.show()

# %%
from IPython import display 
display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Shaqi_jrvej.jpg/375px-Shaqi_jrvej.jpg")
